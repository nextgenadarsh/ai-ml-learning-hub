# %% [markdown]
# # AutoGen Multi-Agent Systems

# %% [markdown]
# ## Agent Roles
#
# Coordinator, assistant, evaluator.

# %% [markdown]
# ## Group Chat Manager
#
# Orchestration in AutoGen.

# %% [markdown]
# ## Exercise
#
# Build multi-agent summarizer pipeline.

# %% [markdown]
# ## Exercises
