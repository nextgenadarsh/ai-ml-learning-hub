# %% [markdown]
# # Haystack Production RAG

# %% [markdown]
# ## Pipeline Setup
#
# Document store + retriever + generator.

# %% [markdown]
# ## Deployment
#
# Elasticsearch / SQL store + API endpoint.

# %% [markdown]
# ## Monitoring
#
# Query logs and drift detection.

# %% [markdown]
# ## Exercises
