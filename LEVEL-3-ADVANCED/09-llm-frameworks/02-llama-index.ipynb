# %% [markdown]
# # LlamaIndex Document Understanding

# %% [markdown]
# ## Index Types
#
# Vector and tree indexes.

# %% [markdown]
# ## Query Engines
#
# From documents to chat interfaces.

# %% [markdown]
# ## Use Case
#
# RAG for customer support knowledge base.

# %% [markdown]
# ## Exercises
