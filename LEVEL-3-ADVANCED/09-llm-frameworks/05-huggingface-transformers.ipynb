# %% [markdown]
# # HuggingFace Transformers

# %% [markdown]
# ## Load Model
#
# from_pretrained usage for GPT and BLOOM.

# %% [markdown]
# ## Optimization
#
# quantization, pipelines.

# %% [markdown]
# ## Serving
#
# Sagemaker/HuggingFace inference endpoints.

# %% [markdown]
# ## Exercises
