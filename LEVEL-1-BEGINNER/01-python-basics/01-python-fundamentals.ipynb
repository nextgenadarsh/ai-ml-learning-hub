# %% [markdown]
# ## 1. Variables and Data Types
#
# Python is dynamically typed - types are inferred automatically.

# %%
# Basic data types
integer_var = 42
float_var = 3.14
string_var = "Hello, Python!"
boolean_var = True
none_var = None

print(f"Type of {integer_var}: {type(integer_var)}")
print(f"Type of {float_var}: {type(float_var)}")
print(f"Type of {string_var}: {type(string_var)}")
print(f"Type of {boolean_var}: {type(boolean_var)}")
print(f"Type of {none_var}: {type(none_var)}")
# Out:
# Type of 42: <class 'int'>
# Type of 3.14: <class 'float'>
# Type of Hello, Python!: <class 'str'>
# Type of True: <class 'bool'>
# Type of None: <class 'NoneType'>

# %% [markdown]
# ## 2. Operators
#
# ### Arithmetic Operators

# %%
a, b = 10, 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")  # Float division
print(f"Integer division: {a} // {b} = {a // b}")
print(f"Modulo: {a} % {b} = {a % b}")
print(f"Exponent: {a} ** {b} = {a ** b}")
# Out:
# Addition: 10 + 3 = 13
# Subtraction: 10 - 3 = 7
# Multiplication: 10 * 3 = 30
# Division: 10 / 3 = 3.3333333333333335
# Integer division: 10 // 3 = 3
# Modulo: 10 % 3 = 1
# Exponent: 10 ** 3 = 1000

# %% [markdown]
# ### Comparison Operators

# %%
x, y = 5, 10

print(f"{x} == {y}: {x == y}")
print(f"{x} != {y}: {x != y}")
print(f"{x} < {y}: {x < y}")
print(f"{x} > {y}: {x > y}")
print(f"{x} <= {y}: {x <= y}")
print(f"{x} >= {y}: {x >= y}")
# Out:
# 5 == 10: False
# 5 != 10: True
# 5 < 10: True
# 5 > 10: False
# 5 <= 10: True
# 5 >= 10: False

# %% [markdown]
# ### Logical Operators

# %%
p, q = True, False

print(f"p and q: {p and q}")
print(f"p or q: {p or q}")
print(f"not p: {not p}")

# Practical example
age = 25
has_license = True
can_drive = age >= 18 and has_license
print(f"Can drive: {can_drive}")
# Out:
# p and q: False
# p or q: True
# not p: False
# Can drive: True

# %% [markdown]
# ## 3. Control Flow
#
# ### If-Else Statements

# %%
score = 85

if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
else:
    grade = 'F'

print(f"Score: {score}, Grade: {grade}")

# Ternary operator (conditional expression)
status = "pass" if score >= 70 else "fail"
print(f"Status: {status}")
# Out:
# Score: 85, Grade: B
# Status: pass

# %% [markdown]
# ### For Loops

# %%
# Iterate over range
print("Numbers 0-4:")
for i in range(5):
    print(i, end=" ")
print()

# Iterate over list
fruits = ['apple', 'banana', 'cherry']
print("\nFruits:")
for fruit in fruits:
    print(f"- {fruit}")

# With enumerate
print("\nFruits with index:")
for index, fruit in enumerate(fruits):
    print(f"  {index}: {fruit}")
# Out:
# Numbers 0-4:
# 0 1 2 3 4
#
# Fruits:
# - apple
# - banana
# - cherry
#
# Fruits with index:
#   0: apple
#   1: banana
#   2: cherry

# %% [markdown]
# ### While Loops

# %%
count = 0
while count < 5:
    print(f"Count: {count}")
    count += 1

# Break and continue
print("\nBreak example:")
for i in range(10):
    if i == 5:
        break
    print(i, end=" ")

print("\n\nContinue example:")
for i in range(5):
    if i == 2:
        continue
    print(i, end=" ")
# Out:
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4
#
# Break example:
# 0 1 2 3 4
#
# Continue example:
# 0 1 3 4

# %% [markdown]
# ## 4. Functions
#
# Functions are reusable blocks of code.

# %%
# Simple function
def greet(name):
    return f"Hello, {name}!"

print(greet("Alice"))

# Multiple parameters
def add(a, b):
    """Add two numbers"""
    return a + b

result = add(5, 3)
print(f"5 + 3 = {result}")

# Default arguments
def power(base, exponent=2):
    return base ** exponent

print(f"2^3 = {power(2, 3)}")
print(f"2^2 = {power(2)}")

# *args (variable number of positional arguments)
def sum_all(*numbers):
    total = 0
    for num in numbers:
        total += num
    return total

print(f"Sum: {sum_all(1, 2, 3, 4, 5)}")

# **kwargs (keyword arguments)
def print_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

print_info(name="Alice", age=30, city="NYC")
# Out:
# Hello, Alice!
# 5 + 3 = 8
# 2^3 = 8
# 2^2 = 4
# Sum: 15
# name: Alice
# age: 30
# city: NYC

# %% [markdown]
# ## 5. Variable Scope
#
# Where variables can be accessed.

# %%
global_var = "I'm global"

def my_function():
    local_var = "I'm local"
    print(f"Inside function - {local_var}")
    print(f"Inside function - {global_var}")

my_function()
print(f"Outside function - {global_var}")

# Accessing local_var outside function will cause error
try:
    print(local_var)
except NameError:
    print("local_var is not defined outside the function")

# Global keyword to modify global variable
counter = 0

def increment():
    global counter
    counter += 1

increment()
increment()
print(f"Counter: {counter}")
# Out:
# Inside function - I'm local
# Inside function - I'm global
# Outside function - I'm global
# local_var is not defined outside the function
# Counter: 2

# %% [markdown]
# ## 6. String Operations
#
# Working with text data.

# %%
# String creation
s1 = "Hello"
s2 = 'World'
s3 = """This is a
multiline string"""

# Concatenation
message = s1 + " " + s2
print(message)

# String methods
text = "Hello World"
print(f"Upper: {text.upper()}")
print(f"Lower: {text.lower()}")
print(f"Capitalize: {text.capitalize()}")
print(f"Length: {len(text)}")
print(f"Replace: {text.replace('World', 'Python')}")
print(f"Split: {text.split()}")

# String indexing and slicing
s = "Python"
print(f"First char: {s[0]}")
print(f"Last char: {s[-1]}")
print(f"Slice [0:3]: {s[0:3]}")
print(f"Slice [2:]: {s[2:]}")

# String formatting
name = "Alice"
age = 30
print(f"Name: {name}, Age: {age}")
# Out:
# Hello World
# Upper: HELLO WORLD
# Lower: hello world
# Capitalize: Hello world
# Length: 11
# Replace: Hello Python
# Split: ['Hello', 'World']
# First char: P
# Last char: n
# Slice [0:3]: Pyt
# Slice [2:]: thon
# Name: Alice, Age: 30

# %% [markdown]
# ## Exercises
#
# **Exercise 1**: Create a function that checks if a number is even or odd.
#
# **Exercise 2**: Write a function that calculates factorial of a number.
#
# **Exercise 3**: Create a function that reverses a string.
#
# **Exercise 4**: Write a function that counts vowels in a text.
#
# **Exercise 5**: Create a temperature converter (Celsius ↔ Fahrenheit).
