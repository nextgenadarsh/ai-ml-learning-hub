# %% [markdown]
# # Prompt Engineering

# %% [markdown]
# ## Prompt Types
#
# Instruction, few-shot, chain-of-thought prompts.

# %% [markdown]
# ## Evaluation
#
# A/B test prompts and temperature tuning.

# %% [markdown]
# ## Safety
#
# Guardrails and failure mode handling.

# %% [markdown]
# ## Exercises
