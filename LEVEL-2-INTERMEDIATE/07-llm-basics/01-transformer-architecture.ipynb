# %% [markdown]
# # Transformer Architecture

# %% [markdown]
# ## Transformer Basics
#
# Transformer block: embedding, self-attention, feed-forward, residuals. Example code to compute attention weights.

# %% [markdown]
# ## Encoder/Decoder for LLM
#
# Encoder vs decoder architecture and why LLMs use decoder-only.

# %% [markdown]
# ## Scaling Laws
#
# Model parameters, compute, dataset size relationship.

# %% [markdown]
# ## Exercises
