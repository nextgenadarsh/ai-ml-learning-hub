# %% [markdown]
# # LLM Models Overview

# %% [markdown]
# ## OpenAI Models
#
# GPT-4, GPT-3.5: usage patterns, strengths, weaknesses.

# %% [markdown]
# ## Meta & Open Source Models
#
# Llama family, Falcon, Mistral; local & cloud deployment.

# %% [markdown]
# ## Embeddings models
#
# text-embedding-3 and use in RAG.

# %% [markdown]
# ## Exercises
