# %% [markdown]
# # LangChain Basics

# %% [markdown]
# ## Core Concepts
#
# LLMChain, PromptTemplate, Memory, Agents.

# %% [markdown]
# ## Simple Example
#
# Build a basic question-answer chain.

# %% [markdown]
# ## RAG with LangChain
#
# Document loaders + retriever pattern.

# %% [markdown]
# ## Exercises
