# %% [markdown]
# # Embedding Models

# %% [markdown]
# ## Embedding Basics
#
# Convert text to vectors and measure similarity.

# %% [markdown]
# ## Vector Stores
#
# Chroma, Weaviate, FAISS sample integration.

# %% [markdown]
# ## Semantic Search
#
# Retrieval augmented generation workflows.

# %% [markdown]
# ## Exercises
