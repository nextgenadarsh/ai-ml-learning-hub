# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Load data
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Preprocess
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)

# One-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

print(f"Training data shape: {X_train.shape}")
print(f"Training labels shape: {y_train.shape}")

# %% [markdown]
# ## Neural Network Architecture
#
# ### Forward Pass
# ```
# Input → Dense(128) → ReLU → Dense(64) → ReLU → Dense(10) → Softmax → Output
# ```
#
# ### Key Components
# - **Input Layer**: Features
# - **Hidden Layers**: Learn representations
# - **Activation Functions**: Introduce non-linearity
# - **Output Layer**: Final predictions
# - **Loss Function**: Measure error
# - **Optimizer**: Update weights

# %%
# Build a simple neural network
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

# Compile
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Model summary
model.summary()

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# Evaluate
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")

# %%
# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(history.history['loss'], label='Training Loss')
axes[0].plot(history.history['val_loss'], label='Validation Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Model Loss')
axes[0].legend()

axes[1].plot(history.history['accuracy'], label='Training Accuracy')
axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Model Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Advanced Topics
#
# ### 1. Convolutional Neural Networks (CNN)
# - Specialized for image data
# - Learns spatial hierarchies
# - Better generalization
#
# ### 2. Recurrent Neural Networks (RNN)
# - For sequential data
# - LSTM and GRU cells
# - Captures temporal dependencies
#
# ### 3. Attention Mechanisms
# - Focus on important parts
# - Transformer architecture
# - Powers modern NLP
#
# ### 4. Transfer Learning
# - Pre-trained models
# - Fine-tuning
# - Reduces training time

# %% [markdown]
# ## Practice Exercises
#
# 1. **Build CNN**: Create a CNN for image classification
# 2. **LSTM Model**: Build an RNN for sequence prediction
# 3. **Hyperparameter Tuning**: Optimize learning rate, batch size, layers
# 4. **Regularization**: Apply dropout, L1/L2 to prevent overfitting
# 5. **Transfer Learning**: Fine-tune a pre-trained model
