# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Generate synthetic data
X, y_true = make_blobs(n_samples=300, centers=4, n_features=2, random_state=42)

# K-Means Clustering
kmeans = KMeans(n_clusters=4, random_state=42)
y_kmeans = kmeans.fit_predict(X)

# Visualization
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# True clusters
axes[0].scatter(X[:, 0], X[:, 1], c=y_true, cmap='viridis')
axes[0].set_title('True Clusters')

# K-Means
axes[1].scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis')
axes[1].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
                c='red', marker='X', s=200, edgecolors='black')
axes[1].set_title('K-Means Clustering')

# DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=5)
y_dbscan = dbscan.fit_predict(X)
axes[2].scatter(X[:, 0], X[:, 1], c=y_dbscan, cmap='viridis')
axes[2].set_title('DBSCAN Clustering')

plt.tight_layout()
plt.show()

# Evaluate
from sklearn.metrics import silhouette_score
print(f"K-Means Silhouette Score: {silhouette_score(X, y_kmeans):.4f}")
print(f"DBSCAN Silhouette Score: {silhouette_score(X, y_dbscan):.4f}")

# %%
from sklearn.decomposition import PCA, TSNE
from sklearn.datasets import load_digits

# Load high-dimensional data
digits = load_digits()
X = digits.data
y = digits.target

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# t-SNE
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

scatter1 = axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='tab10')
axes[0].set_title('PCA Reduction')
axes[0].set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%})')
axes[0].set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%})')

scatter2 = axes[1].scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='tab10')
axes[1].set_title('t-SNE Reduction')

plt.colorbar(scatter1, ax=axes, label='Digit')
plt.tight_layout()
plt.show()

print(f"Original dimensions: {X.shape[1]}")
print(f"PCA dimensions: 2")
print(f"Variance explained by first 2 PCs: {sum(pca.explained_variance_ratio_):.2%}")

# %% [markdown]
# ## Practice Exercises
#
# 1. **Customer Segmentation**: Cluster customer data using K-Means
# 2. **Feature Reduction**: Apply PCA and t-SNE to high-dimensional data
# 3. **Anomaly Detection**: Identify outliers in a dataset
# 4. **Hierarchical Clustering**: Compare different linkage methods
# 5. **Elbow Method**: Find optimal number of clusters
